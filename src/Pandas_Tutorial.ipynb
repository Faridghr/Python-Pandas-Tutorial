# %% [markdown]
# ### Load CSV Data File

# %%
import pandas as pd

df = pd.read_csv('../dataset/pokemon_data.csv')

# %%
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# ### Load TXT File Data

# %%
df_txt = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %%
df_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Reading Data in Pandas

# %% [markdown]
# #### Read Headers

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# #### Read Each Column

# %%
df['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df[['Name', 'Type 1', 'HP']]
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %% [markdown]
# Count / Median / Mean

# %%
df['Legendary'].count()
# Out:
# 800

# %%
df['Speed'].median()
# Out:
# 65.0

# %% [markdown]
# Value Count

# %%
df['Legendary'].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %% [markdown]
# When we want percentage

# %%
df['Legendary'].value_counts(normalize=True)
# Out:
# Legendary
# False    0.91875
# True     0.08125
# Name: proportion, dtype: float64

# %% [markdown]
# #### Read Each Row

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[2:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False

# %% [markdown]
# #### Read a Specific Location (R, C)

# %% [markdown]
# #### iloc

# %%
df.iloc[2, 1]
# Out:
# 'Venusaur'

# %% [markdown]
# ### Loop in DataFrame by Row

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
    if index == 5:
        break
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon

# %% [markdown]
# ### Find a Specific Row

# %% [markdown]
# #### loc

# %%
df.loc[df['Type 1'] == 'Fire'].head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
df.loc[df['Type 1'] == 'Fire', ['Name', 'Attack']].head()
# Out:
#                         Name  Attack
# 4                 Charmander      52
# 5                 Charmeleon      64
# 6                  Charizard      84
# 7  CharizardMega Charizard X     130
# 8  CharizardMega Charizard Y     104

# %% [markdown]
# ### Sorting/Describing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'HP'], ascending=[False, True])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# ...

# %% [markdown]
# ### Explorating in Data

# %% [markdown]
# #### Shape

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# #### Information of Each Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# #### Detailed of Each Columns

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# ### Updating Rows and Columns

# %% [markdown]
# #### Updating Columns

# %%
df.rename(columns={'Name' : 'N', 'Type 1': 'T'}).head()
# if you want to keep changes add -> inplace=True
# df.rename(columns={'Name' : 'N', 'Type 1': 'T'}, inplace=True)
# Out:
#    #                      N      T  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# #### Updating Rows

# %% [markdown]
# With loc

# %%
df.loc[1, ['Generation', 'Legendary']] = [0, True]

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed Generation Legendary
# 0       65     45          1     False
# 1       80     60          0      True
# 2      100     80          1     False
# 3      120     80          1     False
# 4       50     65          1     False

# %%
df.loc[1, ['Generation', 'Legendary']] = [1, False]

# %% [markdown]
# With replace

# %%
df['Name'].replace({'Bulbasaur':'Bul'}).head()
# Out:
# 0                      Bul
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# #### Remove a Row

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed Generation Legendary
# 0       65     45          1     False
# 1       80     60          1     False
# 2      100     80          1     False
# 3      120     80          1     False
# 4       50     65          1     False

# %%
df.drop(index=0).head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed Generation Legendary
# 1       80     60          1     False
# 2      100     80          1     False
# 3      120     80          1     False
# 4       50     65          1     False
# 5       65     80          1     False

# %% [markdown]
# Conditional

# %%
filt = df['Name']=='Bulbasaur'
df.drop(index=df[filt].index).head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed Generation Legendary
# 1       80     60          1     False
# 2      100     80          1     False
# 3      120     80          1     False
# 4       50     65          1     False
# 5       65     80          1     False

# %% [markdown]
# ### Making Changes to the Data

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.sort_values('Total', ascending=False).head()
# Out:
#        #                   Name   Type 1    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 164      194      120    140           1       True    780
# 163      154      100    130           1       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770

# %%
df = df.drop(columns=['Total'])
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Very Important

# %% [markdown]
# Add 'Total' column which is sum of columns 'HP' to 'Speed'

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.iloc[:, 4:10]
# Out:
#      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0    45      49       49       65       65     45
# 1    60      62       63       80       80     60
# 2    80      82       83      100      100     80
# 3    80     100      123      122      120     80
# 4    39      52       43       60       50     65
# ..   ..     ...      ...      ...      ...    ...
# 795  50     100      150      100      150     50
# 796  50     160      110      160      110    110
# 797  80     110       60      150      130     70
# 798  80     160       60      170      130     80
# 799  80     110      120      130       90     70
#
# [800 rows x 6 columns]

# %%
df.iloc[:, 4:10].sum(axis=0)
# Out:
# HP         55407
# Attack     63201
# Defense    59074
# Sp. Atk    58256
# Sp. Def    57522
# Speed      54622
# dtype: int64

# %%
df.iloc[:, 4:10].sum(axis=1)
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Length: 800, dtype: int64

# %% [markdown]
# #### Maping

# %%
df['Legendary'].map({True:'Yes', False:'No'}).head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Legendary, dtype: object

# %% [markdown]
# #### Split

# %%
df['Name'].str.split(' ')
# Out:
# 0                   [Bulbasaur]
# 1                     [Ivysaur]
# 2                    [Venusaur]
# 3      [VenusaurMega, Venusaur]
# 4                  [Charmander]
#                  ...
# 795                   [Diancie]
# 796      [DiancieMega, Diancie]
# 797      [HoopaHoopa, Confined]
# 798       [HoopaHoopa, Unbound]
# 799                 [Volcanion]
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# ### Change Column Order

# %%
cols = list(df.columns.values)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Applying Function to Data

# %% [markdown]
# str.lower()

# %%
df['Name'].str.lower()
# df['Name'] = df['Name'].str.lower()
# Out:
# 0                  bulbasaur
# 1                    ivysaur
# 2                   venusaur
# 3      venusaurmega venusaur
# 4                 charmander
#                ...
# 795                  diancie
# 796      dianciemega diancie
# 797      hoopahoopa confined
# 798       hoopahoopa unbound
# 799                volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# apply()

# %%
df['Name'].apply(len)
# Out:
# 0       9
# 1       7
# 2       8
# 3      21
# 4      10
#        ..
# 795     7
# 796    19
# 797    19
# 798    18
# 799     9
# Name: Name, Length: 800, dtype: int64

# %%
# apply len in columns (number of rows):
df.apply(len)
# Out:
# #             800
# Name          800
# Type 1        800
# Type 2        800
# HP            800
# Attack        800
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
def updateName(name):
    return name.upper()

# %%
df['Name'].apply(updateName)
# Out:
# 0                  BULBASAUR
# 1                    IVYSAUR
# 2                   VENUSAUR
# 3      VENUSAURMEGA VENUSAUR
# 4                 CHARMANDER
#                ...
# 795                  DIANCIE
# 796      DIANCIEMEGA DIANCIE
# 797      HOOPAHOOPA CONFINED
# 798       HOOPAHOOPA UNBOUND
# 799                VOLCANION
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# Lambda Function

# %%
df['Name'].apply(lambda x: x.upper())
# Out:
# 0                  BULBASAUR
# 1                    IVYSAUR
# 2                   VENUSAUR
# 3      VENUSAURMEGA VENUSAUR
# 4                 CHARMANDER
#                ...
# 795                  DIANCIE
# 796      DIANCIEMEGA DIANCIE
# 797      HOOPAHOOPA CONFINED
# 798       HOOPAHOOPA UNBOUND
# 799                VOLCANION
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# str.contains()

# %%
filt = df['Name'].str.contains('Mega')
df.loc[filt, ['Name', 'Type 1']].head()
# Out:
#                          Name Type 1
# 3       VenusaurMega Venusaur  Grass
# 7   CharizardMega Charizard X   Fire
# 8   CharizardMega Charizard Y   Fire
# 12    BlastoiseMega Blastoise  Water
# 19      BeedrillMega Beedrill    Bug

# %% [markdown]
# ### Saving our Data (Exporting into Desired Format)

# %% [markdown]
# csv

# %%
df.to_csv('modified.csv', index=False)

# %% [markdown]
# Excel

# %%
df.to_excel('modified.xlsx', index=False)

# %% [markdown]
# txt

# %%
df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ### Filtering Data

# %%
df['Type 1'] == 'Grass'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
df[df['Type 1'] == 'Grass'].head()
# It is better to use 'loc'
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 48       65     30           1      False

# %% [markdown]
# #### loc

# %%
high_attack = (df['Attack'] > 100)
df.loc[high_attack, ['Name', 'Attack']].head()
# Out:
#                          Name  Attack
# 7   CharizardMega Charizard X     130
# 8   CharizardMega Charizard Y     104
# 12    BlastoiseMega Blastoise     103
# 19      BeedrillMega Beedrill     150
# 39                   Nidoking     102

# %% [markdown]
# and &

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')].head()
# Out:
#      #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49       65
# 1    2                Ivysaur  Grass  Poison  60      62       63       80
# 2    3               Venusaur  Grass  Poison  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 48  43                 Oddish  Grass  Poison  45      50       55       75
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 48       65     30           1      False

# %% [markdown]
# or |

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')].head()
# Out:
#      #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur  Grass  Poison    318  45      49       49
# 1    2                Ivysaur  Grass  Poison    405  60      62       63
# 2    3               Venusaur  Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 16  13                 Weedle    Bug  Poison    195  40      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 16       20       20     50           1      False

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)].head()
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# %%
new_df.head()
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 652  591              Amoonguss  Grass  Poison    464  114      85       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 50       110       90     50           1      False
# 77       100       70     70           1      False
# 652       85       80     30           5      False

# %%
new_df.reset_index().head()
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      2    3               Venusaur  Grass  Poison    525   80      82
# 1      3    3  VenusaurMega Venusaur  Grass  Poison    625   80     100
# 2     50   45              Vileplume  Grass  Poison    490   75      80
# 3     77   71             Victreebel  Grass  Poison    490   80     105
# 4    652  591              Amoonguss  Grass  Poison    464  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       83      100      100     80           1      False
# 1      123      122      120     80           1      False
# 2       85      110       90     50           1      False
# 3       65      100       70     70           1      False
# 4       70       85       80     30           5      False

# %%
new_df.reset_index(drop=True).head()
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
new_df = new_df.reset_index(drop=True)
# or we can use
# new_df.reset_index(drop=True, inplace=True)

# %%
new_df.to_csv('filtered.csv')

# %% [markdown]
# #### isin()

# %%
names = ['Venusaur','Vileplume','Amoonguss','Victreebel']
df['Name'].isin(names).head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
filt = df['Name'].isin(names)
df.loc[filt].head()
# Out:
#        #        Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 2      3    Venusaur  Grass  Poison   80      82       83      100      100
# 50    45   Vileplume  Grass  Poison   75      80       85      110       90
# 77    71  Victreebel  Grass  Poison   80     105       65      100       70
# 652  591   Amoonguss  Grass  Poison  114      85       70       85       80
#
#      Speed  Generation  Legendary
# 2       80           1      False
# 50      50           1      False
# 77      70           1      False
# 652     30           5      False

# %% [markdown]
# ### Regex Filtering

# %%
df.loc[df['Name'].str.contains('Mega')].head()
# Out:
#      #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN    630  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison    495  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 3       122      120     80           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 12      135      115     78           1      False
# 19       15       80    145           1      False

# %% [markdown]
# NOT ~

# %%
df.loc[~df['Name'].str.contains('Mega')].head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     65           1      False
# 5     80           1      False

# %% [markdown]
# Regular Expressions

# %%
import re

df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)].head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Name category started with 'pi[a-z]'

# %%
#  flags=re.I for Uper case and Lower case not important
import re
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)].head()
# Out:
#      #                 Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 20  16               Pidgey    Normal  Flying    251  40      45       40
# 21  17            Pidgeotto    Normal  Flying    349  63      60       55
# 22  18              Pidgeot    Normal  Flying    479  83      80       75
# 23  18  PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 30  25              Pikachu  Electric     NaN    320  35      55       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 20       35       35     56           1      False
# 21       50       50     71           1      False
# 22       70       70    101           1      False
# 23      135       80    121           1      False
# 30       50       50     90           1      False

# %% [markdown]
# ### Conditional Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

df.head()
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur   Grass  Poison    318  45      49       49
# 1  2                Ivysaur   Grass  Poison    405  60      62       63
# 2  3               Venusaur   Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4  4             Charmander  Flamer     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'

df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'Test Value'

df.head()
# Out:
# C:\Users\Farid\AppData\Local\Temp\ipykernel_26132\2418774745.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test Value' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'Test Value'
# C:\Users\Farid\AppData\Local\Temp\ipykernel_26132\2418774745.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Test Value' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'Test Value'
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# ...

# %%
df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']

df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed Generation Legendary
# 0       65       65     45          1     False
# 1       80       80     60          1     False
# 2      100      100     80     Test 1    Test 2
# 3      122      120     80     Test 1    Test 2
# 4       60       50     65          1     False

# %% [markdown]
# Change back

# %%
df = pd.read_csv('modified.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Aggregate Statistics (GroupBy)

# %% [markdown]
# #### Mean

# %% [markdown]
# Task: Which Type have best average defence?

# %%
# df.groupby(['Type 1']).mean()

# %%
# df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)

# %% [markdown]
# #### Sum

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #                                               Name  \
# Type 1
# Bug       23080  CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      14302  UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    15180  DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  15994  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy      7642  ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# Fighting   9824  MankeyPrimeapeMachopMachokeMachampHitmonleeHit...
# Fire      17025  CharmanderCharmeleonCharizardCharizardMega Cha...
# Flying     2711  TornadusIncarnate FormeTornadusTherian FormeNo...
# Ghost     15568  GastlyHaunterGengarGengarMega GengarMisdreavus...
# Grass     24141  BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Ground    11401  SandshrewSandslashDiglettDugtrioCuboneMarowakR...
# Ice       10165  JynxArticunoSwinubPiloswineDelibirdSmoochumSno...
# Normal    31279  PidgeyPidgeottoPidgeotPidgeotMega PidgeotRatta...
# ...

# %% [markdown]
# #### Count

# %%
df.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1
# Bug        69    69      52     69   69      69       69       69       69
# Dark       31    31      21     31   31      31       31       31       31
# Dragon     32    32      21     32   32      32       32       32       32
# Electric   44    44      17     44   44      44       44       44       44
# Fairy      17    17       2     17   17      17       17       17       17
# Fighting   27    27       7     27   27      27       27       27       27
# Fire       52    52      24     52   52      52       52       52       52
# Flying      4     4       2      4    4       4        4        4        4
# Ghost      32    32      22     32   32      32       32       32       32
# Grass      70    70      37     70   70      70       70       70       70
# Ground     32    32      19     32   32      32       32       32       32
# ...

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# Another senario

# %%
groupby_Type = df.groupby(['Type 1'])

groupby_Type['Type 2'].value_counts()
# Out:
# Type 1  Type 2
# Bug     Flying      14
#         Poison      12
#         Steel        7
#         Grass        6
#         Rock         3
#                     ..
# Water   Dragon       2
#         Electric     2
#         Fairy        2
#         Ghost        2
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# More Specific

# %%
groupby_Type['Type 2'].value_counts().loc['Bug']
# Out:
# Type 2
# Flying      14
# Poison      12
# Steel        7
# Grass        6
# Rock         3
# Electric     2
# Ground       2
# Fighting     2
# Fire         2
# Water        1
# Ghost        1
# Name: count, dtype: int64

# %%
groupby_Type['Type 2'].value_counts(normalize=True).loc['Bug']
# Out:
# Type 2
# Flying      0.269231
# Poison      0.230769
# Steel       0.134615
# Grass       0.115385
# Rock        0.057692
# Electric    0.038462
# Fighting    0.038462
# Ground      0.038462
# Fire        0.038462
# Water       0.019231
# Ghost       0.019231
# Name: proportion, dtype: float64

# %% [markdown]
# #### Lambda

# %%
groupby_Type['Type 2'].apply(lambda x: x.str.contains('Flying').sum())
# Out:
# Type 1
# Bug         14
# Dark         5
# Dragon       6
# Electric     5
# Fairy        2
# Fighting     1
# Fire         6
# Flying       0
# Ghost        2
# Grass        5
# Ground       4
# Ice          2
# Normal      24
# Poison       3
# Psychic      6
# Rock         4
# Steel        1
# Water        7
# Name: Type 2, dtype: int64

# %% [markdown]
# .agg([])

# %%
# Group by country, select consumption column, and compute mean and median
#print(be_and_usa.groupby('country')['consumption'].agg([np.mean, np.median]))

# %% [markdown]
# ### Working with large amounts of data

# %%
for df in pd.read_csv('modified.csv', chunksize=50):
    print("Chunk DF")
    print(df.head())
# Out:
# Chunk DF
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# Chunk DF
#      #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 50  45  Vileplume  Grass  Poison    490  75      80       85      110
# 51  46      Paras    Bug   Grass    285  35      70       55       45
# ...

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=50):
    results = df.groupby(['Type 1']).count()
    new_df = pd.concat([new_df, results])

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Check for NaN

# %%
df.isna()

# %% [markdown]
# ##### Drop NaN

# %%
df.dropna() = df.dropna(axis='index', how='any')
df.dropna() = df.dropna(axis='index', how='all')
df.dropna() = df.dropna(axis='index', how='any', subset=['email'])

df.dropna() = df.dropna(axis='columns', how='any')
df.dropna() = df.dropna(axis='columns', how='all')

# %% [markdown]
# ##### For String 'NA' fields
# First change to np.na => df.replace('NA', np.na, inplace=True)
# Then apply dropna() function

# %% [markdown]
# #### Fill NaN fields

# %%
df.fillna()

# %% [markdown]
# #### Change type

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation    object
# Legendary     object
# dtype: object

# %%
df['Generation'] = df['Generation'].astype(int)

# %%
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int32
# Legendary     object
# dtype: object

# %% [markdown]
# #### Replace field

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df['Type 2'].replace('Normal', 'NORMAL', inplace=True)

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'NORMAL'], dtype=object)

# %% [markdown]
# ### Time Series Data
